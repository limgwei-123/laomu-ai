# %%
import math
import numpy as np
import torch
from torch import nn
from d2l import torch as d2l

import nbimporter
import public_function_d3l as d3l

# %%
max_degree = 20
n_train, n_test = 100, 100
true_w = np.zeros(max_degree)
true_w[0:4] = np.array([5,1.2,-3.4,5.6])

features = np.random.normal(size=(n_train + n_test,  1))
np.random.shuffle(features)
poly_features = np.power(features, np.arange(max_degree).reshape(1, -1))
for i in range(max_degree):
    poly_features[:, i] /= math.gamma(i + 1)
labels = np.dot(poly_features, true_w)
labels += np.random.normal(scale = 0.1, size = labels.shape)

# %%
true_w, features, poly_features, labels = [
    torch.tensor(x, dtype = torch.float32)
    for x in [true_w, features, poly_features, labels]]

features[:2], poly_features[:2, :], labels[:2]
# Out:
# (tensor([[-0.3766],
#          [ 1.8307]]),
#  tensor([[ 1.0000e+00, -3.7655e-01,  7.0895e-02, -8.8986e-03,  8.3769e-04,
#           -6.3087e-05,  3.9592e-06, -2.1298e-07,  1.0025e-08, -4.1942e-10,
#            1.5793e-11, -5.4063e-13,  1.6965e-14, -4.9139e-16,  1.3217e-17,
#           -3.3178e-19,  7.8083e-21, -1.7295e-22,  3.6181e-24, -7.1706e-26],
#          [ 1.0000e+00,  1.8307e+00,  1.6757e+00,  1.0225e+00,  4.6798e-01,
#            1.7134e-01,  5.2279e-02,  1.3672e-02,  3.1287e-03,  6.3640e-04,
#            1.1650e-04,  1.9389e-05,  2.9579e-06,  4.1653e-07,  5.4467e-08,
#            6.6474e-09,  7.6057e-10,  8.1903e-11,  8.3299e-12,  8.0259e-13]]),
#  tensor([4.2929, 7.2242]))

# %%
def evaluate_loss (net, data_iter, loss):
    """ 评估损失 """
    metric = d2l.Accumulator(2)
    for X, y in data_iter:
        out = net(X)
        y = y.reshape(out.shape)
        l = loss(out, y)
        metric.add( l.sum(), l.numel())
    return metric[0] / metric[1]

# %%
def train(train_features, test_features, train_labels, test_labels,
          num_epochs=400):
    loss = nn.MSELoss(reduction='none')
    input_shape = train_features.shape[-1]
    # 不设置偏置，因为我们已经在多项式中实现了它
    net = nn.Sequential(nn.Linear(input_shape, 1, bias=False))
    batch_size = min(10, train_labels.shape[0])
    train_iter = d2l.load_array((train_features, train_labels.reshape(-1,1)),
                                batch_size)
    test_iter = d2l.load_array((test_features, test_labels.reshape(-1,1)),
                               batch_size, is_train=False)
    trainer = torch.optim.SGD(net.parameters(), lr=0.01)
    animator = d3l.Animator(xlabel='epoch', ylabel='loss', yscale='log',
                            xlim=[1, num_epochs], ylim=[1e-3, 1e2],
                            legend=['train', 'test'])
    for epoch in range(num_epochs):
        d3l.train_epoch_ch3(net, train_iter, loss, trainer)
        if epoch == 0 or (epoch + 1) % 20 == 0:
            animator.add(epoch + 1, (evaluate_loss(net, train_iter, loss),
                                     evaluate_loss(net, test_iter, loss)))
    print('weight:', net[0].weight.data.numpy())

# %%
# 从多项式特征中选择前4个维度，即1,x,x^2/2!,x^3/3!
train(poly_features[:n_train, :4], poly_features[n_train:, :4],
      labels[:n_train], labels[n_train:])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 2
#       1 # 从多项式特征中选择前4个维度，即1,x,x^2/2!,x^3/3!
# ----> 2 train(poly_features[:n_train, :4], poly_features[n_train:, :4],
#       3       labels[:n_train], labels[n_train:])
#
# Cell In[25], line 17, in train(train_features, test_features, train_labels, test_labels, num_epochs)
#      13 animator = d3l.Animator(xlabel='epoch', ylabel='loss', yscale='log',
#      14                         xlim=[1, num_epochs], ylim=[1e-3, 1e2],
#      15                         legend=['train', 'test'])
#      16 for epoch in range(num_epochs):
# ---> 17     d3l.train_epoch_ch3(net, train_iter, loss, trainer)
#      18     if epoch == 0 or (epoch + 1) % 20 == 0:
#      19         animator.add(epoch + 1, (evaluate_loss(net, train_iter, loss),
#      20                                  evaluate_loss(net, test_iter, loss)))
#
# File ~\Desktop\ai\LAOMU\public_function_d3l.ipynb:10, in train_epoch_ch3(net, train_iter, loss, updater)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "47dcde27-fe87-4d45-84a6-50524b5b0940",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
# ---> 10     "import torch\n",
#      11     "from IPython import display\n",
#      12     "from d2l import torch as d2l"
#      13    ]
#      14   },
#      15   {
#      16    "cell_type": "code",
#      17    "execution_count": 3,
#      18    "id": "b464f334-57b3-420f-83c6-6c15af4126ff",
#      19    "metadata": {},
#      20    "outputs": [],
#      21    "source": [
#      22     "class Accumulator:\n",
#      23     "    def __init__ (self,n):\n",
#      24     "        self.data = [0,0] * n\n",
#      25     "\n",
#      26     "    def add(self, *args):\n",
#      27     "        self.data = [a + float(b) for  a, b in zip(self.data,args)]\n",
#      28     "\n",
#      29     "    def reset(self):\n",
#      30     "        self.data = [0.0] * len(self.data)\n",
#      31     "\n",
#      32     "    def __getitem__(self, idx):\n",
#      33     "        return self.data[idx]"
#      34    ]
#      35   },
#      36   {
#      37    "cell_type": "code",
#      38    "execution_count": 4,
#      39    "id": "8fff37fa-95c7-4d55-bf87-6edcb357d7ec",
#      40    "metadata": {},
#      41    "outputs": [],
#      42    "source": [
#      43     "def train_epoch_ch3(net, train_iter, loss, updater):\n",
#      44     "    if isinstance(net, torch.nn.Module):\n",
#      45     "        net.train()\n",
#      46     "    metric = Accumulator(3)\n",
#      47     "    for X, y in train_iter:\n",
#      48     "        y_hat = net(X)\n",
#      49     "        l = loss (y_hat, y)\n",
#      50     "        if isinstance(updater, torch.optim.Optimizer):\n",
#      51     "            updater.zero_grad()\n",
#      52     "            l.backward()\n",
#      53     "            updater.step()\n",
#      54     "            metric.add(\n",
#      55     "                float(l) * len(y), accuracy(y_hat, y),\n",
#      56     "                y.size().numel())\n",
#      57     "        else:\n",
#      58     "            l.sum().backward()\n",
#      59     "            updater(X.shape[0])\n",
#      60     "            metric.add(float(l.sum()), accuracy(y_hat, y), y.numel())\n",
#      61     "    return metric[0] / metric[2], metric[1] / metric[2]   "
#      62    ]
#      63   },
#      64   {
#      65    "cell_type": "code",
#      66    "execution_count": 5,
#      67    "id": "d4a86b19-059f-444c-9b88-afbb779b0206",
#      68    "metadata": {},
#      69    "outputs": [],
#      70    "source": [
#      71     "class Animator:  #@save\n",
#      72     "    \"\"\"在动画中绘制数据\"\"\"\n",
#      73     "    def __init__(self, xlabel=None, ylabel=None, legend=None, xlim=None,\n",
#      74     "                 ylim=None, xscale='linear', yscale='linear',\n",
#      75     "                 fmts=('-', 'm--', 'g-.', 'r:'), nrows=1, ncols=1,\n",
#      76     "                 figsize=(3.5, 2.5)):\n",
#      77     "        # 增量地绘制多条线\n",
#      78     "        if legend is None:\n",
#      79     "            legend = []\n",
#      80     "        d2l.use_svg_display()\n",
#      81     "        self.fig, self.axes = d2l.plt.subplots(nrows, ncols, figsize=figsize)\n",
#      82     "        if nrows * ncols == 1:\n",
#      83     "            self.axes = [self.axes, ]\n",
#      84     "        # 使用lambda函数捕获参数\n",
#      85     "        self.config_axes = lambda: d2l.set_axes(\n",
#      86     "            self.axes[0], xlabel, ylabel, xlim, ylim, xscale, yscale, legend)\n",
#      87     "        self.X, self.Y, self.fmts = None, None, fmts\n",
#      88     "\n",
#      89     "    def add(self, x, y):\n",
#      90     "        # 向图表中添加多个数据点\n",
#      91     "        if not hasattr(y, \"__len__\"):\n",
#      92     "            y = [y]\n",
#      93     "        n = len(y)\n",
#      94     "        if not hasattr(x, \"__len__\"):\n",
#      95     "            x = [x] * n\n",
#      96     "        if not self.X:\n",
#      97     "            self.X = [[] for _ in range(n)]\n",
#      98     "        if not self.Y:\n",
#      99     "            self.Y = [[] for _ in range(n)]\n",
#     100     "        for i, (a, b) in enumerate(zip(x, y)):\n",
#     101     "            if a is not None and b is not None:\n",
#     102     "                self.X[i].append(a)\n",
#     103     "                self.Y[i].append(b)\n",
#     104     "        self.axes[0].cla()\n",
#     105     "        for x, y, fmt in zip(self.X, self.Y, self.fmts):\n",
#     106     "            self.axes[0].plot(x, y, fmt)\n",
#     107     "        self.config_axes()\n",
#     108     "        display.display(self.fig)\n",
#     109     "        display.clear_output(wait=True)"
#     110    ]
#     111   },
#     112   {
#     113    "cell_type": "code",
#     114    "execution_count": 6,
#     115    "id": "a9885e63-9aeb-4169-a9e7-d0c72e84ff68",
#     116    "metadata": {},
#     117    "outputs": [],
#     118    "source": [
#     119     "def train_ch3(net, train_iter, test_iter, loss, num_epochs, updater):\n",
#     120     "    animator = Animator(xlabel='epoch', xlim=[1, num_epochs], ylim=[0.3, 0.9],\n",
#     121     "                        legend=['train loss', 'train acc', 'test acc'])\n",
#     122     "    for epoch in range(num_epochs):\n",
#     123     "        train_metrics = train_epoch_ch3(net, train_iter, loss, updater)\n",
#     124     "        test_acc = evaluate_accuracy(net, test_iter)\n",
#     125     "        animator.add(epoch+1, train_metrics + (test_acc,))\n",
#     126     "    train_loss, train_acc = train_metrics\n",
#     127     "    assert train_loss < 0.5, train_loss\n",
#     128     "    assert train_acc <= 1 and train_acc > 0.7, train_acc\n",
#     129     "    assert test_acc <=1 and test_acc > 0.7, test_acc"
#     130    ]
#     131   },
#     132   {
#     133    "cell_type": "code",
#     134    "execution_count": null,
#     135    "id": "6a3aa69c-ad18-4e3a-bd45-b3179f701ec7",
#     136    "metadata": {},
#     137    "outputs": [],
#     138    "source": []
#     139   }
#     140  ],
#     141  "metadata": {
#     142   "kernelspec": {
#     143    "display_name": "Python 3 (ipykernel)",
#     144    "language": "python",
#     145    "name": "python3"
#     146   },
#     147   "language_info": {
#     148    "codemirror_mode": {
#     149     "name": "ipython",
#     150     "version": 3
#     151    },
#     152    "file_extension": ".py",
#     153    "mimetype": "text/x-python",
#     154    "name": "python",
#     155    "nbconvert_exporter": "python",
#     156    "pygments_lexer": "ipython3",
#     157    "version": "3.8.20"
#     158   }
#     159  },
#     160  "nbformat": 4,
#     161  "nbformat_minor": 5
#     162 }
#
# File ~\anaconda3\envs\d2l\lib\site-packages\torch\_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~\anaconda3\envs\d2l\lib\site-packages\torch\autograd\__init__.py:282, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     273 inputs = (
#     274     (inputs,)
#     275     if isinstance(inputs, (torch.Tensor, graph.GradientEdge))
#    (...)
#     278     else tuple()
#     279 )
#     281 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 282 grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     283 if retain_graph is None:
#     284     retain_graph = create_graph
#
# File ~\anaconda3\envs\d2l\lib\site-packages\torch\autograd\__init__.py:151, in _make_grads(outputs, grads, is_grads_batched)
#     149 if out.requires_grad:
#     150     if out.numel() != 1:
# --> 151         raise RuntimeError(
#     152             "grad can be implicitly created only for scalar outputs"
#     153         )
#     154     if not out.dtype.is_floating_point:
#     155         msg = (
#     156             "grad can be implicitly created only for real scalar outputs"
#     157             f" but got {out.dtype}"
#     158         )
#
# RuntimeError: grad can be implicitly created only for scalar outputs
